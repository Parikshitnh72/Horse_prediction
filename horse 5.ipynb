# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (1.5.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.2.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC

from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score, roc_curve, auc, confusion_matrix, roc_auc_score
from sklearn.metrics import precision_recall_curve


from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor



from sklearn.model_selection import GridSearchCV

import time
import joblib
import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
# Read the train and test files
df_train = pd.read_csv(r'C:\Users\user\Downloads\df_train.csv')
df_test = pd.read_csv(r'C:\Users\user\Downloads\df_test.csv')

# %%
# View the shape of the train and test files
print(df_train.shape)
print(df_test.shape)
# Out:
# (21139, 27)
# (5286, 27)

# %%
# View the first 2 rows of the train file
df_train.head(2)
# Out:
#    finishing_position  horse_number         horse_name horse_id     jockey  \
# 0                   1           1.0      DOUBLE DRAGON     K019  B Prebble
# 1                   2           2.0  PLAIN BLUE BANNER     S070    D Whyte
#
#         trainer  actual_weight  declared_horse_weight  draw  \
# 0        D Cruz            133                   1032     1
# 1  D E Ferraris            133                   1075    13
#
#   length_behind_winner  ...  running_position_6   race_id  recent_6_runs  \
# 0                    -  ...                 NaN  2014-001              1
# 1                    2  ...                 NaN  2014-001              2
#
#    recent_ave_rank race_distance  HorseWin  HorseRankTop3  \
# 0              1.0          1400         1              1
# 1              2.0          1400         0              1
#
#    HorseRankTop50Percent jockey_ave_rank trainer_ave_rank
# 0                      1        6.058185         7.369681
# 1                      1        5.795734         6.721234
#
# [2 rows x 27 columns]

# %%
# View the first 2 rows of the test files
df_test.head(2)
# Out:
#    finishing_position  horse_number       horse_name horse_id        jockey  \
# 0                   1          11.0      SUPER FLUKE     T382     J Moreira
# 1                   2          10.0  PEARL WARM WARM     T183  S Clipperton
#
#         trainer  actual_weight  declared_horse_weight  draw  \
# 0        D Cruz            118                   1118     6
# 1  P O'Sullivan            118                   1099    12
#
#   length_behind_winner  ...  running_position_6   race_id  recent_6_runs  \
# 0                    -  ...                 NaN  2016-138    1/5/3/2/4/5
# 1                   SH  ...                 NaN  2016-138    2/3/8/7/1/6
#
#    recent_ave_rank race_distance  HorseWin  HorseRankTop3  \
# 0         4.941176          1650         1              1
# 1         5.266667          1650         0              1
#
#    HorseRankTop50Percent jockey_ave_rank trainer_ave_rank
# 0                      1        4.070707         8.052941
# 1                      1        6.714859         6.858209
#
# [2 rows x 27 columns]

# %%
# Keep the features we want to train our model on
X_train = df_train[['actual_weight', 'declared_horse_weight',
                    'draw', #'win_odds', 
                    'jockey_ave_rank',
                    'trainer_ave_rank', 'recent_ave_rank', 'race_distance']]

y_train = df_train['HorseWin']

# Keep the features we want to train our model on
X_test = df_test[['actual_weight', 'declared_horse_weight',
                   'draw', #'win_odds',
                   'jockey_ave_rank',
                    'trainer_ave_rank', 'recent_ave_rank', 'race_distance']]
                    
y_test = df_test[['HorseWin', 'HorseRankTop3']]

# %%
X_train.shape
# Out:
# (21139, 7)

# %%
pip install scikit-learn==0.24.2
# Out:
# Collecting scikit-learn==0.24.2
#   Downloading scikit-learn-0.24.2.tar.gz (7.5 MB)
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB 262.6 kB/s eta 0:00:29
#      ---------------------------------------- 0.1/7.5 MB 327.7 kB/s eta 0:00:23
#       --------------------------------------- 0.1/7.5 MB 492.8 kB/s eta 0:00:16
#      - -------------------------------------- 0.2/7.5 MB 1.0 MB/s eta 0:00:08
#      -- ------------------------------------- 0.4/7.5 MB 1.4 MB/s eta 0:00:06
#      --- ------------------------------------ 0.7/7.5 MB 2.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.8/7.5 MB 2.1 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.0/7.5 MB 2.5 MB/s eta 0:00:03
#      ------ --------------------------------- 1.2/7.5 MB 2.7 MB/s eta 0:00:03
#      ------- -------------------------------- 1.5/7.5 MB 3.0 MB/s eta 0:00:03
#      -------- ------------------------------- 1.7/7.5 MB 3.0 MB/s eta 0:00:02
#      --------- ------------------------------ 1.9/7.5 MB 3.1 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.0/7.5 MB 3.2 MB/s eta 0:00:02
#      ----------- ---------------------------- 2.2/7.5 MB 3.2 MB/s eta 0:00:02
#      ------------ --------------------------- 2.3/7.5 MB 3.2 MB/s eta 0:00:02
#      ------------- -------------------------- 2.6/7.5 MB 3.4 MB/s eta 0:00:02
#      -------------- ------------------------- 2.7/7.5 MB 3.4 MB/s eta 0:00:02
#      --------------- ------------------------ 2.9/7.5 MB 3.5 MB/s eta 0:00:02
#      ---------------- ----------------------- 3.1/7.5 MB 3.6 MB/s eta 0:00:02
#      ----------------- ---------------------- 3.4/7.5 MB 3.6 MB/s eta 0:00:02
#      ------------------ --------------------- 3.6/7.5 MB 3.7 MB/s eta 0:00:02
#      -------------------- ------------------- 3.8/7.5 MB 3.7 MB/s eta 0:00:02
#      -------------------- ------------------- 3.9/7.5 MB 3.8 MB/s eta 0:00:01
#      --------------------- ------------------ 4.1/7.5 MB 3.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.2/7.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 4.5/7.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------- -------------- 4.8/7.5 MB 3.9 MB/s eta 0:00:01
#      -------------------------- ------------- 5.0/7.5 MB 3.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 5.3/7.5 MB 3.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 5.6/7.5 MB 4.0 MB/s eta 0:00:01
#      ------------------------------- -------- 5.9/7.5 MB 4.0 MB/s eta 0:00:01
#      -------------------------------- ------- 6.1/7.5 MB 4.1 MB/s eta 0:00:01
#      --------------------------------- ------ 6.4/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 6.5/7.5 MB 4.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 6.7/7.5 MB 4.1 MB/s eta 0:00:01
#      ------------------------------------- -- 7.0/7.5 MB 4.2 MB/s eta 0:00:01
#      ------------------------------------- -- 7.1/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  7.4/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------- 7.5/7.5 MB 3.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   <string>:17: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   Partial import of sklearn during the build process.
#   Traceback (most recent call last):
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 149, in prepare_metadata_for_build_wheel
#       return hook(metadata_directory, config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-6ilq0ui1\overlay\Lib\site-packages\setuptools\build_meta.py", line 368, in prepare_metadata_for_build_wheel
#       self.run_setup()
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-6ilq0ui1\overlay\Lib\site-packages\setuptools\build_meta.py", line 497, in run_setup
#       super().run_setup(setup_script=setup_script)
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-6ilq0ui1\overlay\Lib\site-packages\setuptools\build_meta.py", line 313, in run_setup
#       exec(code, locals())
#     File "<string>", line 301, in <module>
#     File "<string>", line 293, in setup_package
#   ModuleNotFoundError: No module named 'numpy.distutils'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 23.3.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==0.24.2
# Out:
# Found existing installation: scikit-learn 1.5.0
# Uninstalling scikit-learn-1.5.0:
#   Successfully uninstalled scikit-learn-1.5.0
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\~-learn'.
# You can safely remove it manually.
# Collecting scikit-learn==0.24.2
#   Using cached scikit-learn-0.24.2.tar.gz (7.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   <string>:17: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   Partial import of sklearn during the build process.
#   Traceback (most recent call last):
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 149, in prepare_metadata_for_build_wheel
#       return hook(metadata_directory, config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-b9f4g4g5\overlay\Lib\site-packages\setuptools\build_meta.py", line 368, in prepare_metadata_for_build_wheel
#       self.run_setup()
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-b9f4g4g5\overlay\Lib\site-packages\setuptools\build_meta.py", line 497, in run_setup
#       super().run_setup(setup_script=setup_script)
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-b9f4g4g5\overlay\Lib\site-packages\setuptools\build_meta.py", line 313, in run_setup
#       exec(code, locals())
#     File "<string>", line 301, in <module>
#     File "<string>", line 293, in setup_package
#   ModuleNotFoundError: No module named 'numpy.distutils'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 23.3.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==0.24.2
# Out:
# WARNING: Skipping scikit-learn as it is not installed.
# Collecting scikit-learn==0.24.2
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   <string>:17: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   Partial import of sklearn during the build process.
#   Traceback (most recent call last):
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 149, in prepare_metadata_for_build_wheel
#       return hook(metadata_directory, config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-xy1c7bqi\overlay\Lib\site-packages\setuptools\build_meta.py", line 368, in prepare_metadata_for_build_wheel
#       self.run_setup()
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-xy1c7bqi\overlay\Lib\site-packages\setuptools\build_meta.py", line 497, in run_setup
#       super().run_setup(setup_script=setup_script)
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-xy1c7bqi\overlay\Lib\site-packages\setuptools\build_meta.py", line 313, in run_setup
#       exec(code, locals())
#     File "<string>", line 301, in <module>
#     File "<string>", line 293, in setup_package
#   ModuleNotFoundError: No module named 'numpy.distutils'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 23.3.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached scikit-learn-0.24.2.tar.gz (7.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC

from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score, roc_curve, auc, confusion_matrix, roc_auc_score
from sklearn.metrics import precision_recall_curve


from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

import time
import joblib
import pickle

import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 27
#      24 from sklearn.svm import SVR
#      25 from sklearn.ensemble import GradientBoostingRegressor
# ---> 27 from imblearn.over_sampling import SMOTE
#      28 from imblearn.pipeline import Pipeline
#      29 from sklearn.model_selection import GridSearchCV
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\base.py:20
#      17     from sklearn.base import _OneToOneFeatureMixin as OneToOneFeatureMixin
#      19 from sklearn.preprocessing import label_binarize
# ---> 20 from sklearn.utils import parse_version
#      21 from sklearn.utils.multiclass import check_classification_targets
#      23 from .utils import check_sampling_strategy, check_target_type
#
# ImportError: cannot import name 'parse_version' from 'sklearn.utils' (C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py)

# %%
# Open the pickled models
smote_rfc = joblib.load(r'C:\Users\user\Downloads\smote_rfc_model.pkl')
lgbm = joblib.load(r'C:\Users\user\Downloads\lgbm_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Open the pickled models
# ----> 2 smote_rfc = joblib.load(r'C:\Users\user\Downloads\smote_rfc_model.pkl')
#       3 lgbm = joblib.load(r'C:\Users\user\Downloads\lgbm_model.pkl')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1205, in _Unpickler.load(self)
#    1203             raise EOFError
#    1204         assert isinstance(key, bytes_types)
# -> 1205         dispatch[key[0]](self)
#    1206 except _Stop as stopinst:
#    1207     return stopinst.value
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1530, in _Unpickler.load_stack_global(self)
#    1528 if type(name) is not str or type(module) is not str:
#    1529     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1530 self.append(self.find_class(module, name))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1572, in _Unpickler.find_class(self, module, name)
#    1570     elif module in _compat_pickle.IMPORT_MAPPING:
#    1571         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1572 __import__(module, level=0)
#    1573 if self.proto >= 4:
#    1574     return _getattribute(sys.modules[module], name)[0]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\base.py:20
#      17     from sklearn.base import _OneToOneFeatureMixin as OneToOneFeatureMixin
#      19 from sklearn.preprocessing import label_binarize
# ---> 20 from sklearn.utils import parse_version
#      21 from sklearn.utils.multiclass import check_classification_targets
#      23 from .utils import check_sampling_strategy, check_target_type
#
# ImportError: cannot import name 'parse_version' from 'sklearn.utils' (C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py)

# %%
# find feature importance with random forest
def feature_importance(model, X_train, y_train):
    # fit the model
    model.fit(X_train, y_train)

    # get importance
    importance = model[1][1].feature_importances_

    # sort the index of the importance
    sorted_idx = np.argsort(importance)

    # name of the features
    feature_names = X_train.columns[sorted_idx]

    # summarize feature importance with feature names
    for i,v in enumerate(importance[sorted_idx]):
        print('Feature: %s, Score: %.5f' % (feature_names[i],v))

    # plot a barh graph of feature importance
    plt.figure(figsize=(10, 6))
    plt.barh(feature_names, importance[sorted_idx])
    plt.title('Feature Importance')
    plt.show()

# %%
import joblib

# Load the models
smote_rfc = joblib.load(r'C:\Users\user\Downloads\smote_rfc_model.pkl')
lgbm = joblib.load(r'C:\Users\user\Downloads\lgbm_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 4
#       1 import joblib
#       3 # Load the models
# ----> 4 smote_rfc = joblib.load(r'C:\Users\user\Downloads\smote_rfc_model.pkl')
#       5 lgbm = joblib.load(r'C:\Users\user\Downloads\lgbm_model.pkl')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1205, in _Unpickler.load(self)
#    1203             raise EOFError
#    1204         assert isinstance(key, bytes_types)
# -> 1205         dispatch[key[0]](self)
#    1206 except _Stop as stopinst:
#    1207     return stopinst.value
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1530, in _Unpickler.load_stack_global(self)
#    1528 if type(name) is not str or type(module) is not str:
#    1529     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1530 self.append(self.find_class(module, name))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1572, in _Unpickler.find_class(self, module, name)
#    1570     elif module in _compat_pickle.IMPORT_MAPPING:
#    1571         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1572 __import__(module, level=0)
#    1573 if self.proto >= 4:
#    1574     return _getattribute(sys.modules[module], name)[0]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\base.py:20
#      17     from sklearn.base import _OneToOneFeatureMixin as OneToOneFeatureMixin
#      19 from sklearn.preprocessing import label_binarize
# ---> 20 from sklearn.utils import parse_version
#      21 from sklearn.utils.multiclass import check_classification_targets
#      23 from .utils import check_sampling_strategy, check_target_type
#
# ImportError: cannot import name 'parse_version' from 'sklearn.utils' (C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py)

# %%
import matplotlib.pyplot as plt
import numpy as np

def feature_importance(model, X_train, feature_names):
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1]

    # Print the feature ranking
    print("Feature ranking:")

    for f in range(X_train.shape[1]):
        print(f"{f + 1}. feature {indices[f]} ({importances[indices[f]]})")

    # Plot the feature importances of the model
    plt.figure()
    plt.title("Feature importances")
    plt.bar(range(X_train.shape[1]), importances[indices], align="center")
    plt.xticks(range(X_train.shape[1]), feature_names, rotation=90)
    plt.xlim([-1, X_train.shape[1]])
    plt.show()

# Assuming you have defined X_train and feature_names
# feature_importance(smote_rfc, X_train, feature_names)

# %%
# find feature importance
feature_importance(smote_rfc, X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # find feature importance
# ----> 2 feature_importance(smote_rfc, X_train, y_train)
#
# NameError: name 'smote_rfc' is not defined

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.45.1-cp312-cp312-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.26.2)
# Requirement already satisfied: scipy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.11.4)
# Collecting scikit-learn (from shap)
#   Using cached scikit_learn-1.5.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from shap) (2.1.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from shap) (4.66.2)
# Requirement already satisfied: packaging>20.9 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from shap) (23.2)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba (from shap)
#   Downloading numba-0.60.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting cloudpickle (from shap)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->shap)
#   Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.45.1-cp312-cp312-win_amd64.whl (455 kB)
#    ---------------------------------------- 0.0/455.7 kB ? eta -:--:--
#    -- ------------------------------------- 30.7/455.7 kB ? eta -:--:--
#    ------- -------------------------------- 81.9/455.7 kB 1.5 MB/s eta 0:00:01
#    -------------- ------------------------- 163.8/455.7 kB 1.4 MB/s eta 0:00:01
#    --------------- ------------------------ 174.1/455.7 kB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 358.4/455.7 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  450.6/455.7 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  450.6/455.7 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 455.7/455.7 kB 1.4 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading numba-0.60.0-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.7 MB 7.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.7 MB 4.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.5/2.7 MB 3.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.7 MB 3.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.7 MB 3.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.7 MB 3.6 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.7 MB 3.4 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.7 MB 3.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.7 MB 3.0 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.7 MB 3.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.7 MB 3.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.9/2.7 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.7 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.7 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.0 MB/s eta 0:00:00
# Using cached scikit_learn-1.5.0-cp312-cp312-win_amd64.whl (10.9 MB)
# Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/28.1 MB 4.5 MB/s eta 0:00:07
#    ---------------------------------------- 0.2/28.1 MB 3.1 MB/s eta 0:00:10
#     --------------------------------------- 0.4/28.1 MB 4.0 MB/s eta 0:00:07
#     --------------------------------------- 0.6/28.1 MB 3.7 MB/s eta 0:00:08
#    - -------------------------------------- 0.8/28.1 MB 4.0 MB/s eta 0:00:07
#    - -------------------------------------- 0.8/28.1 MB 3.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.0/28.1 MB 3.7 MB/s eta 0:00:08
#    - -------------------------------------- 1.2/28.1 MB 3.9 MB/s eta 0:00:07
#    - -------------------------------------- 1.4/28.1 MB 3.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.4/28.1 MB 3.3 MB/s eta 0:00:09
#    -- ------------------------------------- 1.6/28.1 MB 3.3 MB/s eta 0:00:08
#    -- ------------------------------------- 1.7/28.1 MB 3.3 MB/s eta 0:00:08
#    -- ------------------------------------- 1.9/28.1 MB 3.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.0/28.1 MB 3.3 MB/s eta 0:00:08
#    -- ------------------------------------- 2.0/28.1 MB 3.2 MB/s eta 0:00:09
#    --- ------------------------------------ 2.1/28.1 MB 2.9 MB/s eta 0:00:09
#    --- ------------------------------------ 2.3/28.1 MB 3.0 MB/s eta 0:00:09
#    --- ------------------------------------ 2.5/28.1 MB 3.0 MB/s eta 0:00:09
#    --- ------------------------------------ 2.8/28.1 MB 3.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.9/28.1 MB 3.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.0/28.1 MB 3.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.2/28.1 MB 3.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.4/28.1 MB 3.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.6/28.1 MB 3.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.8/28.1 MB 3.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.9/28.1 MB 3.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.1/28.1 MB 3.1 MB/s eta 0:00:08
#    ------ --------------------------------- 4.2/28.1 MB 3.2 MB/s eta 0:00:08
#    ------ --------------------------------- 4.5/28.1 MB 3.2 MB/s eta 0:00:08
#    ------ --------------------------------- 4.7/28.1 MB 3.3 MB/s eta 0:00:08
#    ------ --------------------------------- 4.8/28.1 MB 3.3 MB/s eta 0:00:08
#    ------- -------------------------------- 5.0/28.1 MB 3.3 MB/s eta 0:00:08
#    ------- -------------------------------- 5.2/28.1 MB 3.3 MB/s eta 0:00:08
#    ------- -------------------------------- 5.3/28.1 MB 3.3 MB/s eta 0:00:07
#    ------- -------------------------------- 5.4/28.1 MB 3.3 MB/s eta 0:00:07
#    ------- -------------------------------- 5.5/28.1 MB 3.2 MB/s eta 0:00:07
#    -------- ------------------------------- 5.6/28.1 MB 3.2 MB/s eta 0:00:07
#    -------- ------------------------------- 5.8/28.1 MB 3.2 MB/s eta 0:00:07
#    -------- ------------------------------- 5.9/28.1 MB 3.2 MB/s eta 0:00:07
#    -------- ------------------------------- 6.1/28.1 MB 3.2 MB/s eta 0:00:07
#    --------- ------------------------------ 6.4/28.1 MB 3.3 MB/s eta 0:00:07
#    --------- ------------------------------ 6.5/28.1 MB 3.2 MB/s eta 0:00:07
#    --------- ------------------------------ 6.7/28.1 MB 3.3 MB/s eta 0:00:07
#    --------- ------------------------------ 6.8/28.1 MB 3.3 MB/s eta 0:00:07
#    --------- ------------------------------ 7.0/28.1 MB 3.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 7.2/28.1 MB 3.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 7.3/28.1 MB 3.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 7.4/28.1 MB 3.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 7.6/28.1 MB 3.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 7.7/28.1 MB 3.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 7.9/28.1 MB 3.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 8.1/28.1 MB 3.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 8.3/28.1 MB 3.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 8.4/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------ --------------------------- 8.5/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------ --------------------------- 8.6/28.1 MB 3.3 MB/s eta 0:00:06
#    ------------ --------------------------- 8.8/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------ --------------------------- 9.0/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------- -------------------------- 9.1/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------- -------------------------- 9.4/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------- -------------------------- 9.5/28.1 MB 3.4 MB/s eta 0:00:06
#    ------------- -------------------------- 9.6/28.1 MB 3.3 MB/s eta 0:00:06
#    ------------- -------------------------- 9.6/28.1 MB 3.3 MB/s eta 0:00:06
#    ------------- -------------------------- 9.7/28.1 MB 3.3 MB/s eta 0:00:06
#    -------------- ------------------------- 9.9/28.1 MB 3.3 MB/s eta 0:00:06
#    -------------- ------------------------- 9.9/28.1 MB 3.3 MB/s eta 0:00:06
#    -------------- ------------------------- 10.1/28.1 MB 3.3 MB/s eta 0:00:06
#    -------------- ------------------------- 10.2/28.1 MB 3.3 MB/s eta 0:00:06
#    -------------- ------------------------- 10.4/28.1 MB 3.2 MB/s eta 0:00:06
#    -------------- ------------------------- 10.4/28.1 MB 3.2 MB/s eta 0:00:06
#    --------------- ------------------------ 10.6/28.1 MB 3.2 MB/s eta 0:00:06
#    --------------- ------------------------ 10.7/28.1 MB 3.2 MB/s eta 0:00:06
#    --------------- ------------------------ 10.9/28.1 MB 3.2 MB/s eta 0:00:06
#    --------------- ------------------------ 11.1/28.1 MB 3.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 11.3/28.1 MB 3.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 11.6/28.1 MB 3.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 11.7/28.1 MB 3.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 11.9/28.1 MB 3.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.1/28.1 MB 3.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.3/28.1 MB 3.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.5/28.1 MB 3.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.6/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------ --------------------- 12.7/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------ --------------------- 12.9/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------ --------------------- 13.1/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------ --------------------- 13.3/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------- -------------------- 13.4/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------- -------------------- 13.5/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------- -------------------- 13.8/28.1 MB 3.4 MB/s eta 0:00:05
#    ------------------- -------------------- 13.9/28.1 MB 3.4 MB/s eta 0:00:05
#    -------------------- ------------------- 14.1/28.1 MB 3.5 MB/s eta 0:00:05
#    -------------------- ------------------- 14.3/28.1 MB 3.5 MB/s eta 0:00:04
#    -------------------- ------------------- 14.4/28.1 MB 3.5 MB/s eta 0:00:04
#    -------------------- ------------------- 14.5/28.1 MB 3.4 MB/s eta 0:00:04
#    -------------------- ------------------- 14.6/28.1 MB 3.4 MB/s eta 0:00:04
#    -------------------- ------------------- 14.7/28.1 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 14.8/28.1 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 14.9/28.1 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 15.1/28.1 MB 3.3 MB/s eta 0:00:04
#    --------------------- ------------------ 15.3/28.1 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 15.5/28.1 MB 3.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.7/28.1 MB 3.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.8/28.1 MB 3.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.9/28.1 MB 3.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 16.0/28.1 MB 3.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 16.1/28.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.2/28.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.3/28.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.5/28.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.6/28.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.6/28.1 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.8/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------ --------------- 17.0/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------ --------------- 17.1/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------ --------------- 17.3/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------ --------------- 17.4/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------- -------------- 17.6/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------- -------------- 17.8/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------- -------------- 17.9/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------- -------------- 18.1/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------- -------------- 18.2/28.1 MB 3.2 MB/s eta 0:00:04
#    -------------------------- ------------- 18.4/28.1 MB 3.2 MB/s eta 0:00:04
#    -------------------------- ------------- 18.5/28.1 MB 3.2 MB/s eta 0:00:04
#    -------------------------- ------------- 18.6/28.1 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 18.7/28.1 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 18.9/28.1 MB 3.1 MB/s eta 0:00:03
#    --------------------------- ------------ 19.0/28.1 MB 3.1 MB/s eta 0:00:03
#    --------------------------- ------------ 19.2/28.1 MB 3.1 MB/s eta 0:00:03
#    --------------------------- ------------ 19.3/28.1 MB 3.1 MB/s eta 0:00:03
#    --------------------------- ------------ 19.5/28.1 MB 3.1 MB/s eta 0:00:03
#    --------------------------- ------------ 19.7/28.1 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.8/28.1 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 20.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 20.1/28.1 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 20.2/28.1 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 20.3/28.1 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 20.4/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.5/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.6/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.7/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.9/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ------------------------------ --------- 21.6/28.1 MB 3.0 MB/s eta 0:00:03
#    ------------------------------- -------- 21.9/28.1 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 22.0/28.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------------- -------- 22.2/28.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------------- -------- 22.3/28.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------------- -------- 22.4/28.1 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.5/28.1 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.5/28.1 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.6/28.1 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.7/28.1 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.9/28.1 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 22.9/28.1 MB 2.9 MB/s eta 0:00:02
#    -------------------------------- ------- 23.2/28.1 MB 2.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.3/28.1 MB 2.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.5/28.1 MB 2.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.6/28.1 MB 2.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.9/28.1 MB 2.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.0/28.1 MB 2.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.2/28.1 MB 2.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.4/28.1 MB 2.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.7/28.1 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.8/28.1 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 25.0/28.1 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 25.2/28.1 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.2/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 25.4/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 25.6/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 25.7/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 25.9/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 25.9/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 25.9/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 26.0/28.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 26.2/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 26.3/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 26.5/28.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 26.7/28.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 26.8/28.1 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 27.0/28.1 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 27.1/28.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  27.4/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: slicer, llvmlite, cloudpickle, scikit-learn, numba, shap
# Successfully installed cloudpickle-3.0.0 llvmlite-0.43.0 numba-0.60.0 scikit-learn-1.5.0 shap-0.45.1 slicer-0.0.8
# [notice] A new release of pip is available: 23.3.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# SHAP values
import shap

# fit the model
lgbm.fit(X_train, y_train)

# Create object that can calculate shap values
explainer = shap.Explainer(lgbm.predict, X_test)

# Calculate Shap values
shap_values = explainer(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       2 import shap
#       4 # fit the model
# ----> 5 lgbm.fit(X_train, y_train)
#       7 # Create object that can calculate shap values
#       8 explainer = shap.Explainer(lgbm.predict, X_test)
#
# NameError: name 'lgbm' is not defined

# %%
# Plot the SHAP values
shap.plots.beeswarm(shap_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Plot the SHAP values
# ----> 2 shap.plots.beeswarm(shap_values)
#
# NameError: name 'shap_values' is not defined
